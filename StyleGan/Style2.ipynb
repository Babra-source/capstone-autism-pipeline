# %%
# !git clone https://github.com/clovaai/stargan-v2.git
# Out:
# Cloning into 'stargan-v2'...

# %%
cd stargan-v2
# Out:
# c:\Users\HomePC\OneDrive - Ashesi University\Desktop\Year 4 sem 2\Thesis 2\Autism_Emotional_Detection_Code\StyleGan\stargan-v2

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp313-cp313-win_amd64.whl.metadata (27 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# ...
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
# ...

# %%
source_dir = r"C:\Users\HomePC\OneDrive - Ashesi University\Desktop\Year 4 sem 2\Thesis 2\Autism_Emotional_Detection_Code\data\Autism emotion recogition dataset/data/train"
dest_dir = r"C:\Users\HomePC\OneDrive - Ashesi University\Desktop\Year 4 sem 2\Thesis 2\Autism_Emotional_Detection_Code\StyleGan\Generate"
checkpoint_dir = r"C:\Users\HomePC\OneDrive - Ashesi University\Desktop\Year 4 sem 2\Thesis 2\Autism_Emotional_Detection_Code\StyleGan\checkpoint"

# %%
# %cd stargan-v2
# Out:
# [WinError 2] The system cannot find the file specified: 'stargan-v2'
# c:\Users\HomePC\OneDrive - Ashesi University\Desktop\Year 4 sem 2\Thesis 2\Autism_Emotional_Detection_Code\StyleGan\stargan-v2

# %%
# !python train.py --dataset="{source_dir}" --image_size=256 --batch_size=16 --num_domains=4 --checkpoint_dir="{checkpoint_dir}" --resume=None
# Out:
# python: can't open file 'c:\\Users\\HomePC\\OneDrive - Ashesi University\\Desktop\\Year 4 sem 2\\Thesis 2\\Autism_Emotional_Detection_Code\\StyleGan\\stargan-v2\\train.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/clovaai/stargan-v2.git
cd stargan-v2

# Install required packages
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install -r requirements.txt

# -------------------------------
# 2️⃣ Define Paths (Windows style)
# -------------------------------
source_dir = r"C:\Users\HomePC\Documents\stargan_dataset\train"
dest_dir = r"C:\Users\HomePC\Documents\stargan_dataset\gen"
checkpoint_dir = r"C:\Users\HomePC\Documents\stargan_dataset\stargan_v2_ckpt"

import os
os.makedirs(dest_dir, exist_ok=True)
os.makedirs(checkpoint_dir, exist_ok=True)

# -------------------------------
# 3️⃣ Download Pretrained Checkpoint (optional for demo)
# -------------------------------
import urllib.request
import zipfile

ckpt_url = "https://github.com/clovaai/stargan-v2/releases/download/v0.0.1/stargan-v2.zip"
ckpt_zip = os.path.join(checkpoint_dir, "stargan_v2.zip")
urllib.request.urlretrieve(ckpt_url, ckpt_zip)

with zipfile.ZipFile(ckpt_zip, 'r') as zip_ref:
    zip_ref.extractall(checkpoint_dir)

# -------------------------------
# 4️⃣ Train on Your Dataset (optional)
# -------------------------------
# Only needed if you want your synthetic faces to resemble your 1500 images
# !python train.py ^
--dataset="{source_dir}" ^
--image_size=256 ^
--batch_size=16 ^
--num_domains=4 ^
--checkpoint_dir="{checkpoint_dir}" ^
--resume=None

# -------------------------------
# 5️⃣ Generate Synthetic Faces
# -------------------------------
# !python demo.py ^
--source="{source_dir}" ^
--dest="{dest_dir}" ^
--checkpoint_dir="{checkpoint_dir}" ^
--mode="sample" ^
--num_domains=4 ^
--image_size=256
# Out:
#   Cell In[6], line 2
#     pip3 install --quiet ml4a
#          ^
# SyntaxError: invalid syntax
